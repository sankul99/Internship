# %% [markdown]
# <br><font face = "Times New Roman" size = "4"> <b>Name: Sankul Pandey  DS0722
# <br><font face = "Times New Roman" size = "4"> <b>Email: sankul99@gmail.com
#
#
#
#
#
#
#
# <br><font face = "Muller Text" size = "8"> <b> HR Analytics Project
#
#
#
#
#
# <br><font face = "TImes New Roman" size = "4"> <b> Project Description

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and
# money in training those employees, not just this but there are training programs within the
# companies for their existing employees as well. The aim of these programs is to increase the
# effectiveness of their employees. But where HR Analytics fit in this? and is it just about
# improving the performance of employees?

# %% [markdown]
# <br><font face = "TImes New Roman" size = "4"> <b> Problem Statement

# %% [markdown]
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to
# applying analytic processes to the human resource department of an organization in the hope of
# improving employee performance and therefore getting a better return on investment. HR
# analytics does not just deal with gathering data on employee efficiency. Instead, it aims to
# provide insight into each process by gathering data and then using it to make relevant
# decisions about how to improve these processes.
#
# Attrition in HR
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general,
# relatively high attrition is problematic for companies. HR professionals often assume a
# leadership role in designing company compensation programs, work culture, and motivation
# systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition?
# We will discuss the first question here and for the second question, we will write the code and
# try to understand the process step by step.
#
# Attrition affecting Companies
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring
# processes, paperwork, and new hire training are some of the common expenses of losing
# employees and replacing them. Additionally, regular employee turnover prohibits your
# organization from increasing its collective knowledge base and experience over time. This is
# especially concerning if your business is customer-facing, as customers often prefer to interact
# with familiar people. Errors and issues are more likely if you constantly have new workers.
#
# Dataset Link-
#
# https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics

# %% [markdown]
# # 1) Necessary Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pickle 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2) Importing Data

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv") # Reading the data file
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # 3) Checking the Data

# %% [markdown]
# <br><font face = "Muller Text" size = "4"> We will check data for multiple things such as it's shape, what the data tells us about itself and also things like null values present and etc

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# <br><font face = "Verdana" size = "3"> Till now we have observed that data
#
# 1. Only has int and obj data types
#
# 2. Has no null values
#
# 3. is of 1470 ,35 size

# %%
dupli = df[df.duplicated()]
print("Duplicate rows are as follows ")

dupli
# Out:
# Duplicate rows are as follows
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# <br><font face = "Verdana" size = "2"> So There are no duplicate rows as well
#
# ### Below we will remove the unwanted columns and then compare the two datasets

# %%
dfm = df.dropna()

print(dfm.shape)
print(df.shape)
# Out:
# (1470, 35)
# (1470, 35)

# %%
dff = dfm.drop(columns=['EmployeeCount', 'StandardHours', 'EmployeeNumber','Over18'])

print(dff.shape), print(dfm.shape), print(df.shape)
# Out:
# (1470, 31)
# (1470, 35)
# (1470, 35)
# (None, None, None)

# %% [markdown]
# # 4) Checking Skewness

# %%
dff.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
#We will see the heatmap and try and understand the data 

plt.figure(figsize=(26,8))
sns.heatmap(dff.corr(), annot= True, linewidths=0.2, linecolor="Black", fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5) EDA analysis Or Visual Analysis of the data

# %%
dff.plot.line(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
dff.hist(figsize=(20,35),layout=(10,5),bins=15,legend=True)
plt.show()

# %% [markdown]
# <br><font face = "Verdana" size = "3"> It is clear from the above visualisation that line plot seems kind of useless here as it doesn't help much with the understanding of the data,
# Histogram plot is much better and helps us understand the individual columns a little better.
#
# It is clear we will be needing individual analysis with each and every data here to understand the data much better
#
# There is also the reason that being int and obj individual analysis of each column will tell us more and lead us better towards the outcome which is to understand the realtionship between HR and the employees

# %% [markdown]
# ### 1) Age

# %%
dff['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
plt.plot()
dff['Age'].hist(grid=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age & Count')
plt.show()

# %%
plt.plot()
sns.distplot(dff['Age'])
plt.show()

# %%
plt.plot()
sns.boxplot(dff['Age'])
plt.show()

# %%
plt.plot()
sns.countplot(data = dff, x='Age', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# <br><font face = "Verdana" size = "2"> For Age columns
#
# 1. Displot tells us that there are no outliers
# 2. Boxplot tells us that max people are between the age 20 and 30
# 3. Countplot tells us that Employee attrition maximum in the 26 to 34

# %% [markdown]
# ### 2 ) Attrition
#
# <br><font face = "Verdana" size = "2">
#
# 1. Attrition means the employee leaving the company
# 2. here 0 means that employee has no left and 1 means that employee has left the company
# 3. Attrition is also our target variable

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dff['Attrition']=le.fit_transform(dff['Attrition'])

#Label encoder is used to change categorical value to numerical value between 0 and 1

# %%
dff['Attrition'].describe()
# Out:
# count    1470.000000
# mean        0.161224
# std         0.367863
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Attrition, dtype: float64

# %%
sns.countplot(data = df, x='Attrition')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
plt.plot()
sns.distplot(dff['Attrition'])
plt.show()

# %% [markdown]
# <br><font face = "Verdana" size = "2">  We don't need to visualise any  further
#
# it is clear from the above two plots that there is some imbalance present in this dataset when it comes to our target variable.
# we will rectify this ahead

# %% [markdown]
# ### 3) Business Travel

# %%
le=LabelEncoder()
dff['BusinessTravel']=le.fit_transform(dff['BusinessTravel'])

# %%
dff['BusinessTravel'].describe()
# Out:
# count    1470.000000
# mean        1.607483
# std         0.665455
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         2.000000
# Name: BusinessTravel, dtype: float64

# %%
sns.countplot(data = df, x='BusinessTravel')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['BusinessTravel'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['BusinessTravel'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='BusinessTravel', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
plt.plot()
sns.countplot(data = df, x='BusinessTravel', hue='Department')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# <br><font face = "Verdana" size = "2">
#
# Observation of Business Travel
#
#
# 1. Countplot tells us that people from sales travel rarely
#
# 2. It also compares all of them and tells us that Human resource travels the least and R & D travels the most

# %% [markdown]
# ### 4) Daily rate

# %%
dff['DailyRate'].describe()
# Out:
# count    1470.000000
# mean      802.485714
# std       403.509100
# min       102.000000
# 25%       465.000000
# 50%       802.000000
# 75%      1157.000000
# max      1499.000000
# Name: DailyRate, dtype: float64

# %%
sns.countplot(data = df, x='DailyRate')
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['DailyRate'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['DailyRate'])
plt.show()

# %%
plt.plot()
df['DailyRate'].hist()
plt.xlabel('DailyRate')
plt.ylabel('Count')
plt.title('Daily Rate with Count')
plt.show()

# %% [markdown]
# ###  5) Department

# %%
le=LabelEncoder()
dff['Department']=le.fit_transform(dff['Department'])

# %%
df['Department'].describe()
# Out:
# count                       1470
# unique                         3
# top       Research & Development
# freq                         961
# Name: Department, dtype: object

# %%
sns.countplot(data = df, x='Department')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['Department'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['Department'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='Department', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# Research and Development department is the biggest here followed by sales and lastly human resources which is the smallest department

# %% [markdown]
# ### 6) Distance from home

# %%
dff['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
sns.countplot(data = df, x='DistanceFromHome')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['DistanceFromHome'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['DistanceFromHome'])
plt.show()

# %%
plt.plot()
df['DistanceFromHome'].hist()
plt.xlabel('DistanceFromHome')
plt.ylabel('Count')
plt.title('Distance from home with Count of people')
plt.show()

# %% [markdown]
# ### 7) Education

# %%
df['Education'].describe()
# Out:
# count    1470.000000
# mean        2.912925
# std         1.024165
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Education, dtype: float64

# %%
sns.countplot(data = df, x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['Education'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['Education'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='Education', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# ### 8) Education Field

# %%
le=LabelEncoder()
dff['EducationField']=le.fit_transform(dff['EducationField'])

# %%
df['EducationField'].describe()
# Out:
# count              1470
# unique                6
# top       Life Sciences
# freq                606
# Name: EducationField, dtype: object

# %%
sns.countplot(data = df, x='EducationField')
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['EducationField'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['EducationField'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='EducationField', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# We will be dropping column numbers
#
# 9. EmployeeCount
# 10. EmployeeNumber
#
# as we don't have much data in these two columns

# %% [markdown]
# ### 11) Environment Satisfaction

# %%
df['EnvironmentSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.721769
# std         1.093082
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: EnvironmentSatisfaction, dtype: float64

# %%
sns.countplot(data = df, x='EnvironmentSatisfaction')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['EnvironmentSatisfaction'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['EnvironmentSatisfaction'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='EnvironmentSatisfaction', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# ### 12) Gender

# %%
dff['Gender'].replace(['Male','Female'],[0,1],inplace=True)

#This is done to get a better understanding of the male and female demographic

# %%
df['Gender'].describe()
# Out:
# count     1470
# unique       2
# top       Male
# freq       882
# Name: Gender, dtype: object

# %%
sns.countplot(data = df, x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['Gender'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['Gender'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='Gender', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### 13) Hourly Rate

# %%
df['HourlyRate'].describe()
# Out:
# count    1470.000000
# mean       65.891156
# std        20.329428
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        83.750000
# max       100.000000
# Name: HourlyRate, dtype: float64

# %%
sns.countplot(data = df, x='HourlyRate')
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['HourlyRate'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['HourlyRate'])
plt.show()

# %% [markdown]
# ### 14) Job Involvement

# %%
df['JobInvolvement'].describe()
# Out:
# count    1470.000000
# mean        2.729932
# std         0.711561
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: JobInvolvement, dtype: float64

# %%
sns.countplot(data = df, x='JobInvolvement')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['JobInvolvement'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['JobInvolvement'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='JobInvolvement', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
label=df['JobInvolvement'].unique()
y=df['JobInvolvement'].value_counts()
plt.title('Job Involvement')
plt.pie(y,labels=label,autopct='%.0f%%',shadow=True)
plt.show()

# %% [markdown]
# ### 15) Job Role

# %%
print(df['JobRole'].unique())
print(df['JobRole'].value_counts())

#Checking and counting the unique values of Job Role
# Out:
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
le=LabelEncoder()
dff['JobRole']=le.fit_transform(dff['JobRole'])

# %%
sns.countplot(data = df, x='JobRole')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['JobRole'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['JobRole'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='JobRole', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
label=df['JobRole'].unique()
y=df['JobRole'].value_counts()
plt.title('Job Role')
plt.pie(y,labels=label,autopct='%.0f%%',shadow=True)
plt.show()

# %% [markdown]
# ### 16) Job Satisfaction

# %%
sns.countplot(data = df, x='JobSatisfaction')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['JobSatisfaction'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['JobSatisfaction'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='JobSatisfaction', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
label=df['JobSatisfaction'].unique()
y=df['JobSatisfaction'].value_counts()
plt.title('Job Satisfaction ')
plt.pie(y,labels=label,autopct='%.0f%%',shadow=True)
plt.show()

# %% [markdown]
# ### 17) Maritial Status

# %%
le=LabelEncoder()
dff['MaritalStatus']=le.fit_transform(dff['MaritalStatus'])

# %%
print(df['MaritalStatus'].unique())
print(df['MaritalStatus'].value_counts())

#Checking and counting the unique values of Maritial Status
# Out:
# ['Single' 'Married' 'Divorced']
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(data = df, x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['MaritalStatus'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['JobSatisfaction'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='MaritalStatus', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
label=df['MaritalStatus'].unique()
y=df['MaritalStatus'].value_counts()
plt.title('Marital Status of the Employees ')
plt.pie(y,labels=label,autopct='%.0f%%',shadow=True)
plt.show()

# %% [markdown]
# ### 18) Monthly Income

# %%
df['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
sns.countplot(data = df, x='MonthlyIncome')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['MonthlyIncome'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['MonthlyIncome'])
plt.show()

# %%
plt.plot()
sns.countplot(data = df, x='MonthlyIncome', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='count'>

# %%
#Countplot seems like it won't be able to help us so we will use catplot

plt.plot()
sns.catplot(data = df, y='MonthlyIncome', x='Attrition')

# %% [markdown]
# We can observe that
#
# 1. Minimal Outliers are present
# 2. Maximum amount of employees are earning under 10K
# 3. max attrition can be found at an around 7500 to 500

# %% [markdown]
# ### 19) Monthly Rate

# %%
df['MonthlyRate'].describe()
# Out:
# count     1470.000000
# mean     14313.103401
# std       7117.786044
# min       2094.000000
# 25%       8047.000000
# 50%      14235.500000
# 75%      20461.500000
# max      26999.000000
# Name: MonthlyRate, dtype: float64

# %%
sns.countplot(data = df, x='MonthlyRate')
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['MonthlyRate'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['MonthlyRate'])
plt.show()

# %%
# Monthly income and Monthly rate are similar so we will directly use cat plot here 

plt.plot()
sns.catplot(data = df, y='MonthlyRate', x='Attrition')

# %% [markdown]
# Here we can say that outliers are not present at all data is quite normalized and also that attrition in this case is evenly spread out

# %% [markdown]
# ### 20) Number of Companies Worked in

# %%
df['NumCompaniesWorked'].describe()
# Out:
# count    1470.000000
# mean        2.693197
# std         2.498009
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         9.000000
# Name: NumCompaniesWorked, dtype: float64

# %%
sns.countplot(data = df, x='NumCompaniesWorked')
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['NumCompaniesWorked'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['NumCompaniesWorked'])
plt.show()

# %%
sns.countplot(data=df, x="NumCompaniesWorked", hue="Attrition")
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %%
plt.plot()
sns.catplot(data = df, y='NumCompaniesWorked', x='Attrition')

# %% [markdown]
# ### 21) Overtime done by Employees

# %%
le=LabelEncoder()
dff['OverTime']=le.fit_transform(dff['OverTime'])

# %%
dff['OverTime'].describe()
# Out:
# count    1470.000000
# mean        0.282993
# std         0.450606
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: OverTime, dtype: float64

# %%
sns.countplot(data = df, x='OverTime')
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['OverTime'])
plt.show()

#Data distributed evenly

# %%
plt.plot()
sns.distplot(dff['OverTime'])
plt.show()

# %%
sns.countplot(data=df, x="OverTime", hue="Attrition")
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# ### 22) Percentage Salary Hike Given To Employees

# %%
dff['PercentSalaryHike'].describe()
# Out:
# count    1470.000000
# mean       15.209524
# std         3.659938
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64

# %%
sns.countplot(data = df, x='PercentSalaryHike')
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %%
plt.plot()
sns.boxplot(dff['PercentSalaryHike'])
plt.show()

# %%
plt.plot()
sns.distplot(dff['PercentSalaryHike'])
plt.show()

# %%
sns.countplot(data=df, x="PercentSalaryHike", hue="Attrition")
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %% [markdown]
# # 6) Visualising and Removing Outliers From All Columns

# %%
dff.plot(kind='box',subplots=True,layout=(8,8),figsize=(25,25))
plt.show()

# %% [markdown]
# <br><font face = "Muller Text" size = "3">
#
# Feature will act as input and label will act as an output
# we will drop our target variable and then use it as an output

# %%
f2 = dff.drop('Attrition', axis=1)
label = dff['Attrition']

# %%
#We will install imblearn because we don't have it installed 

# !pip install imblearn

# %% [markdown]
# <br><font face = "Muller Text" size = "3"> SMOTE is used to increase the number of sample sizes
# this will increase the data required in our data set and will do it in a balanced way

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()

# %%
train_x,train_y=smt.fit_resample(f2,label)

# %%
train_y.value_counts()
# Out:
# 0    1233
# 1    1233
# Name: Attrition, dtype: int64

# %%
dfz = pd.DataFrame(train_x)

# %%
dfz['Attrition']= train_y

# %%
dfz.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0               1                        2       1          94  ...
# 1               1                        3       0          61  ...
# 2               4                        4       0          92  ...
# 3               1                        4       1          56  ...
# 4               3                        1       0          40  ...
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
dfz.shape
# Out:
# (2466, 31)

# %%
from scipy.stats import zscore 
z =np.abs(zscore(dfz))
threshold = 3    
dfinal = dfz[(z<3).all(axis=1)]
print('Percentage of loss of the data by the zscore method is :',(dfz.shape[0]-dfinal.shape[0])/dfz.shape[0])
# Out:
# Percentage of loss of the data by the zscore method is : 0.10746147607461476

# %%
x= dfinal.drop('Attrition', axis= 1)

# %%
y = dfinal['Attrition']

# %%
x.skew()
# Out:
# Age                         0.579146
# BusinessTravel             -0.910394
# DailyRate                   0.102847
# Department                  0.143173
# DistanceFromHome            0.767435
# Education                  -0.144114
# EducationField              0.622894
# EnvironmentSatisfaction    -0.019586
# Gender                      0.919645
# HourlyRate                 -0.013385
# JobInvolvement             -0.333855
# JobLevel                    0.989885
# JobRole                    -0.352043
# JobSatisfaction             0.009073
# MaritalStatus              -0.161259
# MonthlyIncome               1.449569
# MonthlyRate                 0.036076
# NumCompaniesWorked          1.050513
# OverTime                    1.011753
# PercentSalaryHike           0.776886
# PerformanceRating           2.694834
# RelationshipSatisfaction   -0.059405
# StockOptionLevel            1.006538
# TotalWorkingYears           1.137061
# TrainingTimesLastYear       0.523783
# ...

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline

# %%
scaler = MinMaxScaler(feature_range=(1,2))
power=PowerTransformer(method='box-cox')
pipe= Pipeline(steps=[('s',scaler),('p',power)])

# %%
data= pipe.fit_transform(x)

# %%
x=pd.DataFrame(data,columns=x.columns)

# %%
x.head()
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0  0.837453        0.838405   0.886205    1.536431         -1.478865
# 1  1.570883       -0.982670  -1.358238   -0.305797         -0.027838
# 2  0.413197        0.838405   1.534038   -0.305797         -1.217863
# 3 -0.058691       -0.982670   1.578147   -0.305797         -0.978229
# 4 -0.876872        0.838405  -0.448515   -0.305797         -1.217863
#
#    Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0  -0.780900       -0.923761                -0.413479  1.560031    1.523465
# 1  -1.765833       -0.923761                 0.522765 -0.641013   -0.238574
# 2  -0.780900        1.384463                 1.417822 -0.641013    1.418548
# 3   1.347993       -0.923761                 1.417822  1.560031   -0.512019
# 4  -1.765833        0.817187                -1.404121 -0.641013   -1.401003
#
#    ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
x.skew()
# Out:
# Age                         0.010357
# BusinessTravel             -0.452354
# DailyRate                  -0.031252
# Department                  0.017958
# DistanceFromHome            0.116408
# Education                  -0.041627
# EducationField              0.061528
# EnvironmentSatisfaction    -0.081418
# Gender                      0.919645
# HourlyRate                 -0.050927
# JobInvolvement             -0.040448
# JobLevel                    0.276088
# JobRole                    -0.176544
# JobSatisfaction            -0.075272
# MaritalStatus              -0.094482
# MonthlyIncome               0.219739
# MonthlyRate                -0.049610
# NumCompaniesWorked          0.170241
# OverTime                    1.011753
# PercentSalaryHike           0.091628
# PerformanceRating           2.694834
# RelationshipSatisfaction   -0.087019
# StockOptionLevel            0.472092
# TotalWorkingYears           0.038863
# TrainingTimesLastYear       0.001531
# ...

# %% [markdown]
# <br><font face = "Muller Text" size = "3"> We have sucessfully removed the excess skewness in our target data

# %% [markdown]
# # 7) Variance Inflation Factor

# %% [markdown]
# <br><font face = "Muller Text" size = "3"> Variance inflation factor or VIF will tell us how much the behaviour of an individual variable  is influenced or changes when in correlation with another independent variable

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def viz():
    viz=pd.DataFrame()
    viz['Variables']= x.columns
    viz['Variance Inflation Factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return viz

# %%
viz()
# Out:
#                    Variables  Variance Inflation Factor
# 0                        Age                   2.039594
# 1             BusinessTravel                   1.062758
# 2                  DailyRate                   1.042771
# 3                 Department                   2.336587
# 4           DistanceFromHome                   1.057047
# 5                  Education                   1.090396
# 6             EducationField                   1.056580
# 7    EnvironmentSatisfaction                   1.081521
# 8                     Gender                   1.065290
# 9                 HourlyRate                   1.034361
# 10            JobInvolvement                   1.102385
# 11                  JobLevel                   5.413228
# 12                   JobRole                   2.089947
# 13           JobSatisfaction                   1.096345
# 14             MaritalStatus                   1.762171
# 15             MonthlyIncome                   5.648150
# ...

# %% [markdown]
# <br><font face = "Muller Text" size = "3"> We will see the above table and drop the variables that have the same VIF factor
# by observing the above table we can see that
#
# 1. Business Travel variable and Daily Rate have same variable inflation factor
#
# 2. Environment Satisfaction and Job Involvement has same variable inflation factor
#
# 3. Percent Salary Hike and Performance Rating has same variable inflation factor
#
# 4. Distance From Home and Education Variables has same variable inflation factor
#
# 5. Gender and Hourly Rate has same variable inflation factor

# %%
x.drop('DailyRate',inplace=True,axis=1)
x.drop('JobInvolvement',axis=1,inplace=True)
x.drop('PerformanceRating',axis=1,inplace=True)
x.drop('Education',axis=1,inplace=True)
x.drop('HourlyRate',axis=1,inplace=True)

# %%
x.shape
# Out:
# (2201, 25)

# %% [markdown]
# # 8) Standard Scaler

# %% [markdown]
# <br><font face = "Muller Text" size = "3">  Standard Scaler is performed after the outlers are removed from the data. Standard Scaler will remove the means of the each individual variable and scales them to a unit

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
x = scale.fit_transform(x)
x.shape
# Out:
# (2201, 25)

# %% [markdown]
# # 9) Model Building

# %% [markdown]
# <br><font face = "Muller Text" size = "3"> For model building we would have to use certain models.
# these models will be seggregated into
#
#
# 1. Classification models
# 2. Model selection
# 3. Metrics
#
# We will import all the necessary libraries below

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score

# %%
lg=LogisticRegression()
svc=SVC()
gnb=GaussianNB()
knc=KNeighborsClassifier()
dtc=DecisionTreeClassifier()
gbc=GradientBoostingClassifier()
rfc=RandomForestClassifier()
abc=AdaBoostClassifier()

# %%
list_of_models = [lg,svc,gnb,knc,dtc,gbc,rfc,abc]

# %%
def confusion_plot():
    print('accuracy_score:-',accuracy_score(pred,y_test))
    print(classification_report(pred,y_test))
    matrix = confusion_matrix(pred,y_test)
    sns.heatmap(matrix, annot=True, fmt="d", cmap='Blues', square=True)
    plt.xlabel("predicted")
    plt.show()

# %%
#Logistic Regression

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score:',maxacc,'Random State:',maxrn)
# Out:
# Accuracy Score: 0.8517397881996974 Random State: 43

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=74)
lg.fit(x_train,y_train)
pred=lg.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8396369137670197
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       287
#            1       0.87      0.84      0.86       374
#
#     accuracy                           0.84       661
#    macro avg       0.84      0.84      0.84       661
# weighted avg       0.84      0.84      0.84       661

# %%
#SVC

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    svc.fit(x_train,y_train)
    pred=svc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score :',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score : 0.9016641452344932 Random State : 10

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=9)
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8744326777609682
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87       302
#            1       0.90      0.87      0.88       359
#
#     accuracy                           0.87       661
#    macro avg       0.87      0.88      0.87       661
# weighted avg       0.88      0.87      0.87       661

# %%
# Gaussian NB

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    gnb.fit(x_train,y_train)
    pred=gnb.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score : ',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score :  0.7957639939485628 Random State : 10

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=46)
gnb.fit(x_train,y_train)
pred=gnb.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.7579425113464447
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.75       326
#            1       0.75      0.79      0.77       335
#
#     accuracy                           0.76       661
#    macro avg       0.76      0.76      0.76       661
# weighted avg       0.76      0.76      0.76       661

# %%
# K Neighbours Classifier 

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    knc.fit(x_train,y_train)
    pred=knc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score :',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score : 0.875945537065053 Random State : 40

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=74)
knc.fit(x_train,y_train)
pred=knc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8260211800302572
#               precision    recall  f1-score   support
#
#            0       0.67      0.94      0.78       216
#            1       0.96      0.77      0.86       445
#
#     accuracy                           0.83       661
#    macro avg       0.81      0.85      0.82       661
# weighted avg       0.86      0.83      0.83       661

# %%
# Decision Tree Classifier 

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score :',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score : 0.848714069591528 Random State : 57

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=21)
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.7866868381240545
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76       291
#            1       0.82      0.79      0.81       370
#
#     accuracy                           0.79       661
#    macro avg       0.78      0.79      0.78       661
# weighted avg       0.79      0.79      0.79       661

# %%
# Gradient Boosting Classifier 

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    gbc.fit(x_train,y_train)
    pred=gbc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score :',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score : 0.9062027231467473 Random State : 37

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=39)
gbc.fit(x_train,y_train)
pred=gbc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8819969742813918
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       299
#            1       0.89      0.90      0.89       362
#
#     accuracy                           0.88       661
#    macro avg       0.88      0.88      0.88       661
# weighted avg       0.88      0.88      0.88       661

# %%
# Random Forest Classifier 

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    rfc.fit(x_train,y_train)
    pred=rfc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score : ',maxacc,'Random State :',maxrn)
# Out:
# Accuracy Score :  0.9273827534039334 Random State : 39

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=74)
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8850226928895613
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       295
#            1       0.91      0.89      0.90       366
#
#     accuracy                           0.89       661
#    macro avg       0.88      0.88      0.88       661
# weighted avg       0.89      0.89      0.89       661

# %%
# Ada Boost Classifier 

maxacc=0
maxrn=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    abc.fit(x_train,y_train)
    pred=abc.predict(x_test)
    score=accuracy_score(pred,y_test)
    if score>maxacc:
        maxacc=score
        maxrn=i
print('Accuracy Score : ',maxacc,'Random state :',maxrn)
# Out:
# Accuracy Score :  0.8850226928895613 Random state : 43

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=40)
abc.fit(x_train,y_train)
pred=abc.predict(x_test)
confusion_plot()
# Out:
# accuracy_score:- 0.8441754916792739
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       310
#            1       0.84      0.88      0.86       351
#
#     accuracy                           0.84       661
#    macro avg       0.85      0.84      0.84       661
# weighted avg       0.84      0.84      0.84       661

# %% [markdown]
# <br><font face = "Muller Text" size = "4"> From the above model building it is clear that the best accuracy is with the Random Forest Classifer
#
# Not only that the Random State accuracy score is much better than all the model combined as a higher score means thre are less randomness in the data.
#
#
# Therefore we will be considering the Random Forest Classifer model as our best model for the particular data set and the target variable

# %% [markdown]
# # 10) Hyperparameter Tuning and Cross Validation

# %%
for model in list_of_models:
    score=cross_val_score(model,x,y,cv=5)
    print(model)
    print(score)
    print(score.mean())
# Out:
# LogisticRegression()
# [0.65759637 0.875      0.84318182 0.83863636 0.86363636]
# 0.8156101834673264
# SVC()
# [0.70294785 0.92045455 0.88409091 0.87272727 0.90227273]
# 0.8564986600700886
# GaussianNB()
# [0.67120181 0.76136364 0.75       0.76136364 0.76363636]
# 0.7415130900845186
# KNeighborsClassifier()
# [0.81179138 0.87727273 0.84090909 0.825      0.86590909]
# 0.8441764584621728
# DecisionTreeClassifier()
# [0.66439909 0.83409091 0.83181818 0.77272727 0.85681818]
# 0.7919707276850134
# GradientBoostingClassifier()
# [0.68480726 0.93409091 0.90227273 0.89090909 0.91363636]
# 0.8651432694289838
# RandomForestClassifier()
# [0.7414966  0.94318182 0.93181818 0.92272727 0.93181818]
# 0.8942084106369821
# AdaBoostClassifier()
# [0.63945578 0.90227273 0.85681818 0.85454545 0.90227273]
# 0.8310729746444032

# %%
random_forest_params={'max_features': ['auto', 'sqrt', 'log2'],'criterion' :['gini', 'entropy']}

# %%
rfc_gridcv = GridSearchCV(rfc, random_forest_params, cv=5)
rfc_gridcv.fit(x_train,y_train)
print('Best Score:', rfc_gridcv.best_score_)
print('Best Score:', rfc_gridcv.best_params_)
print('Best Score:', rfc_gridcv.best_estimator_)
# Out:
# Best Score: 0.8993506493506495
# Best Score: {'criterion': 'entropy', 'max_features': 'sqrt'}
# Best Score: RandomForestClassifier(criterion='entropy')

# %%
grid_pred=rfc_gridcv.predict(x_test)

# %%
def confusion_plotfinal():
    print('Accuracy Score :',accuracy_score(grid_pred,y_test))
    print(rfc_gridcv.best_estimator_)
    print(rfc_gridcv.best_params_)
    print('Classification Report')
    print(classification_report(grid_pred,y_test))
    matrix = confusion_matrix(grid_pred,y_test)
    sns.heatmap(matrix, annot=True, fmt="d", cmap='Oranges', square=True)
    plt.xlabel("predicted")
    plt.show()

# %%
confusion_plotfinal()
# Out:
# Accuracy Score : 0.869894099848714
# RandomForestClassifier(criterion='entropy')
# {'criterion': 'entropy', 'max_features': 'sqrt'}
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       300
#            1       0.88      0.88      0.88       361
#
#     accuracy                           0.87       661
#    macro avg       0.87      0.87      0.87       661
# weighted avg       0.87      0.87      0.87       661
